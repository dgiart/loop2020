# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /home/art/loop2020/loop03_2020/Jup03_2020

# %%
# !ls
# Out:
# B125v.txt		    save.p			Zi400v12.txt
# B400v12.txt		    TestNewEnergy03_2020.ipynb	Zv125i10.txt
# Bias55_125_400.ipynb	    Untitled1.ipynb		Zv125i12.txt
# BiasesToFile eps=0.8.ipynb  Untitled.ipynb		Zv125v10.txt
# BiasesToFile eps=1.0.ipynb  Zi125i10.txt		Zv125v12.txt
# BiasesToFile eps=1.2.ipynb  Zi125i12.txt		Zv400v12.txt
# BiasRe55_inv_eps.ipynb	    Zi125v10.txt
# RESULTS			    Zi125v12.txt

# %%
B55v=pickle.load(open('RESULTS/B55v.txt','rb'))
B55v10=pickle.load(open('RESULTS/B55v10.txt','rb'))
B55v12=pickle.load(open('RESULTS/B55v12.txt','rb'))

# %%
l=np.linspace(1.,3.5,15)
R=10**l
R=np.append([6,7,8,9],R)

# %%
plt.plot(R,B55v,'*',R,B55v10,'v',R,B55v12,'^')
plt.semilogx()
plt.show()

# %%
x=np.linspace(0,5,100)
y=x*x
plt.loglog(x,y)
# plt.semilogx()
plt.show()

# %%
import sys
sys.path.append('../')
from l2020_iz_anizotropic import LiebmanAniz

# %%
Zi=LiebmanAniz('one',0.8,5,55,3000, P=358.146, _w=1.95, dr=.5,dz=.5,form='aniz')['flow']
Zv=LiebmanAniz('one',0.8,5,55,3000, P=-179.073, _w=1.95, dr=.5,dz=.5,form='aniz')['flow']
b=1-Zv/Zi
print (f'b={b}')
# Out:
# start with jit and CALC!:  Thu Mar 12 21:18:29 2020
# FINISH IZotropic iterating with jit, T=12.702872276306152, flow=2.5791704642695503
# ****************************************
#
# ANIZ!count=100, flow=4.364838089016345,e=1, dev=10,w=1.95,T=12.835929155349731
# ANIZ!count=200, flow=4.346724568844694,e=2.5479102586596788e-05, dev=0.0005784853900046063,w=1.95,T=13.011409759521484
# ANIZ!count=300, flow=4.346403472285411,e=6.518504233307053e-07, dev=9.630484822812576e-05,w=1.95,T=13.13959002494812
# Finish !count=364, flow=4.3463930278212395,e=9.745036672042108e-08, dev=7.866438589677656e-05,w=1.95,T=13.222022294998169
# Time for anizotropic=0.5121784210205078
# DONE with  13.223228454589844
# start with jit and CALC!:  Thu Mar 12 21:18:43 2020
# FINISH IZotropic iterating with jit, T=4.716658353805542, flow=2.5791704642695503
# ****************************************
#
# ANIZ!count=100, flow=3.0068756379561083,e=1, dev=10,w=1.95,T=4.85957407951355
# ...

# %%
Zi=LiebmanAniz('one',1.,5,55,3000, P=358.146, _w=1.95, dr=.5,dz=.5,form='aniz')['flow']
Zv=LiebmanAniz('one',1.,5,55,3000, P=-179.073, _w=1.95, dr=.5,dz=.5,form='aniz')['flow']
b=1-Zv/Zi
print (f'b={b}')
# Out:
# start with jit and CALC!:  Thu Mar 12 21:19:11 2020
# FINISH IZotropic iterating with jit, T=4.42363977432251, flow=2.5791704642695503
# ****************************************
#
# ANIZ!count=100, flow=4.986905624855605,e=1, dev=10,w=1.95,T=4.565391302108765
# ANIZ!count=200, flow=4.957085141825291,e=2.676679245926911e-05, dev=0.0005331671982261639,w=1.95,T=4.704457998275757
# Finish !count=258, flow=4.956601165553836,e=8.577546575868776e-08, dev=9.212484609252725e-05,w=1.95,T=4.781367778778076
# Time for anizotropic=0.35069942474365234
# DONE with  4.782536029815674
# start with jit and CALC!:  Thu Mar 12 21:19:16 2020
# FINISH IZotropic iterating with jit, T=4.395728826522827, flow=2.5791704642695503
# ****************************************
#
# ANIZ!count=100, flow=3.18784145922214,e=1, dev=10,w=1.95,T=4.5355544090271
# ANIZ!count=200, flow=3.210950994112319,e=2.3734917978603587e-05, dev=0.0012449833056292791,w=1.95,T=4.675463676452637
# ...

# %%
Zi=LiebmanAniz('one',1.2,5,55,3000, P=358.146, _w=1.95, dr=.5,dz=.5,form='aniz')['flow']
Zv=LiebmanAniz('one',1.2,5,55,3000, P=-179.073, _w=1.95, dr=.5,dz=.5,form='aniz')['flow']
b=1-Zv/Zi
print (f'b={b}')
# Out:
# start with jit and CALC!:  Thu Mar 12 21:20:46 2020
# FINISH IZotropic iterating with jit, T=4.518033742904663, flow=2.5791704642695503
# ****************************************
#
# ANIZ!count=100, flow=5.6575970531975655,e=1, dev=10,w=1.95,T=4.656381607055664
# ANIZ!count=200, flow=5.615553349210611,e=2.7393569751984267e-05, dev=0.00039690904419326524,w=1.95,T=4.804189205169678
# Finish !count=233, flow=5.615129129049047,e=3.168701121408551e-08, dev=8.251984274447272e-05,w=1.95,T=4.863134860992432
# Time for anizotropic=0.33829522132873535
# DONE with  4.864761114120483
# start with jit and CALC!:  Thu Mar 12 21:20:51 2020
# FINISH IZotropic iterating with jit, T=4.895592451095581, flow=2.5791704642695503
# ****************************************
#
# ANIZ!count=100, flow=3.3926465591709305,e=1, dev=10,w=1.95,T=5.0546863079071045
# ANIZ!count=200, flow=3.4180621296769758,e=2.7828938906903754e-05, dev=0.0013927492821124892,w=1.95,T=5.190159797668457
# ...

# %%
import sys
sys.path.append('../')
from l2020_iz_anizotropic import LiebmanAniz

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time
# %matplotlib inline
l=np.linspace(1.,3.5,15)
R=10**l
R=np.append([6,7,8,9],R)
print(f'R: {R}')
Zv=[]
Zi=[]
start=time()
for r in R:
    t=time()
    zv=LiebmanAniz('one',0.8,5,55,r, P=179.073, _w=1.95, dr=.5,dz=.5,form='aniz')
    Zv.append(zv['flow'])
    zi=LiebmanAniz('one',0.8,5,55,r, P=-358.146, _w=1.95, dr=.5,dz=.5,form='aniz')
    Zi.append(zi['flow'])
    print (f"R={r}, Zv={zv['flow']}, Zi={zi['flow']},B={1-zv['flow']/zi['flow']}, T={time()-t}")
           
           
Zv=np.array(Zv)
Zi=np.array(Zi)
B=1-Zv/Zi
plt.plot(R,B,'*')
plt.semilogx()
plt.show()
print (f'DONE {time()-start}')
# Out:
# R: [   6.            7.            8.            9.           10.
#    15.08590709   22.75845926   34.33320018   51.79474679   78.13707377
#   117.87686348  177.827941    268.26957953  404.70899508  610.54022966
#   921.05531769 1389.49549437 2096.17999245 3162.27766017]
# start with jit and CALC!:  Fri Mar 13 09:50:16 2020
# FINISH IZotropic iterating with jit, T=14.58766222000122, flow=3.6656157565005243
# ****************************************
#
# ANIZ!count=100, flow=3.7410265086064145,e=1, dev=10,w=1.95,T=14.663856744766235
# ANIZ!count=200, flow=3.7437546983744854,e=1.1379511065338216e-06, dev=0.002146496746892311,w=1.95,T=14.735260248184204
# Finish !count=287, flow=3.7439788501901408,e=9.62210289527296e-08, dev=0.0021806787081197735,w=1.95,T=14.796275854110718
# Time for anizotropic=0.20509600639343262
# DONE with  14.796924352645874
# start with jit and CALC!:  Fri Mar 13 09:50:31 2020
# FINISH IZotropic iterating with jit, T=9.578046798706055, flow=3.6656157565005243
# ****************************************
#
# ANIZ!count=100, flow=4.018943769643419,e=1, dev=10,w=1.95,T=9.65586519241333
# ANIZ!count=200, flow=4.031416792905637,e=3.6664548123156726e-06, dev=0.004627862610589908,w=1.95,T=9.728963851928711
# ANIZ!count=300, flow=4.0322156644573415,e=2.744479768697697e-07, dev=0.004756433363356073,w=1.95,T=9.802826881408691
# Finish !count=338, flow=4.032254827825005,e=9.965663118598894e-08, dev=0.004762901447723546,w=1.95,T=9.831166505813599
# Time for anizotropic=0.24966955184936523
# DONE with  9.831844806671143
# R=6.0, Zv=3.7439788501901408, Zi=4.032254827825005,B=0.07149249984043293, T=24.986437559127808
# start with jit and CALC!:  Fri Mar 13 09:50:41 2020
# FINISH IZotropic iterating with jit, T=14.971165895462036, flow=3.4166634660221837
# ****************************************
#
# ANIZ!count=100, flow=3.5106781715011612,e=1, dev=10,w=1.95,T=15.048735618591309
# Finish !count=153, flow=3.513248846588747,e=6.446735930591002e-08, dev=0.0020583498463381156,w=1.95,T=15.087419271469116
# Time for anizotropic=0.11261582374572754
# DONE with  15.088096857070923
# start with jit and CALC!:  Fri Mar 13 09:50:56 2020
# FINISH IZotropic iterating with jit, T=9.76744794845581, flow=3.4166634660221837
# ****************************************
#
# ANIZ!count=100, flow=3.808354241512083,e=1, dev=10,w=1.95,T=9.846285343170166
# ANIZ!count=200, flow=3.821798782302302,e=4.137339399149821e-06, dev=0.004169797310413202,w=1.95,T=9.920278549194336
# ANIZ!count=300, flow=3.822638897254044,e=2.9704433501896027e-07, dev=0.004311810588146404,w=1.95,T=9.995460748672485
# Finish !count=341, flow=3.8226810511272067,e=9.935371147237054e-08, dev=0.00431913049260793,w=1.95,T=10.026365518569946
# Time for anizotropic=0.2553136348724365
# DONE with  10.027047157287598
# R=7.0, Zv=3.513248846588747, Zi=3.8226810511272067,B=0.08094638302277835, T=25.460047006607056
# start with jit and CALC!:  Fri Mar 13 09:51:06 2020
# FINISH IZotropic iterating with jit, T=15.03084397315979, flow=3.232047338191343
# ****************************************
#
# ANIZ!count=100, flow=3.3418109339114084,e=1, dev=10,w=1.95,T=15.10959529876709
# Finish !count=130, flow=3.3440051977938254,e=4.022591526152072e-09, dev=0.0018953259556489489,w=1.95,T=15.131719827651978
# Time for anizotropic=0.09725475311279297
# DONE with  15.132375717163086
# start with jit and CALC!:  Fri Mar 13 09:51:22 2020
# FINISH IZotropic iterating with jit, T=9.907785654067993, flow=3.232047338191343
# ****************************************
#
# ANIZ!count=100, flow=3.657379803480151,e=1, dev=10,w=1.95,T=9.98894739151001
# ANIZ!count=200, flow=3.671509299127652,e=4.511103795178627e-06, dev=0.004308201086567016,w=1.95,T=10.063688516616821
# ANIZ!count=300, flow=3.672371346741444,e=3.0728364224311133e-07, dev=0.004459608401154658,w=1.95,T=10.13944673538208
# Finish !count=343, flow=3.6724148501980802,e=9.789309978348176e-08, dev=0.0044674645530399255,w=1.95,T=10.17257285118103
# Time for anizotropic=0.261246919631958
# DONE with  10.17327618598938
# R=8.0, Zv=3.3440051977938254, Zi=3.6724148501980802,B=0.08942607679155345, T=25.759373664855957
# start with jit and CALC!:  Fri Mar 13 09:51:32 2020
# FINISH IZotropic iterating with jit, T=15.274663925170898, flow=3.0903805353836358
# ****************************************
#
# ANIZ!count=100, flow=3.2154421209098603,e=1, dev=10,w=1.95,T=15.353904962539673
# ANIZ!count=200, flow=3.219487655476252,e=1.3266126608732672e-06, dev=0.00203453241245382,w=1.95,T=15.42860746383667
# Finish !count=296, flow=3.2198112018089753,e=9.975428185869314e-08, dev=0.0020787505356931048,w=1.95,T=15.501118183135986
# Time for anizotropic=0.22279858589172363
# DONE with  15.5018310546875
# start with jit and CALC!:  Fri Mar 13 09:51:48 2020
# FINISH IZotropic iterating with jit, T=10.112488269805908, flow=3.0903805353836358
# ****************************************
#
# ANIZ!count=100, flow=3.5407294149786614,e=1, dev=10,w=1.95,T=10.194468975067139
# ANIZ!count=200, flow=3.5553276591122724,e=4.7343272584488005e-06, dev=0.004214702265293705,w=1.95,T=10.270835876464844
# ANIZ!count=300, flow=3.5561982854496668,e=3.263039566100273e-07, dev=0.004371970816590965,w=1.95,T=10.349725246429443
# Finish !count=343, flow=3.5562413900512544,e=9.914056461977211e-08, dev=0.004379965034276418,w=1.95,T=10.385546684265137
# Time for anizotropic=0.2693164348602295
# DONE with  10.38626480102539
# R=9.0, Zv=3.2198112018089753, Zi=3.5562413900512544,B=0.0946027424300998, T=26.220531940460205
# start with jit and CALC!:  Fri Mar 13 09:51:58 2020
# FINISH IZotropic iterating with jit, T=15.401494026184082, flow=2.978790124226793
# ****************************************
#
# ANIZ!count=100, flow=3.1161207015811083,e=1, dev=10,w=1.95,T=15.480068445205688
# ANIZ!count=200, flow=3.1204411353424826,e=1.1830794424128044e-06, dev=0.0018291672371907619,w=1.95,T=15.555803775787354
# Finish !count=295, flow=3.120781804101237,e=9.61747228332005e-08, dev=0.001871250907915762,w=1.95,T=15.627769708633423
# Time for anizotropic=0.2226393222808838
# DONE with  15.628841161727905
# start with jit and CALC!:  Fri Mar 13 09:52:14 2020
# FINISH IZotropic iterating with jit, T=10.172499418258667, flow=2.978790124226793
# ****************************************
#
# ANIZ!count=100, flow=3.453901866171509,e=1, dev=10,w=1.95,T=10.253816366195679
# ANIZ!count=200, flow=3.4688429158403307,e=4.93033713601463e-06, dev=0.004152451658041129,w=1.95,T=10.330898761749268
# ANIZ!count=300, flow=3.469715111799683,e=3.081996335085879e-07, dev=0.004313299186715588,w=1.95,T=10.410978555679321
# Finish !count=343, flow=3.4697575242544314,e=9.893433224224257e-08, dev=0.004321289096378315,w=1.95,T=10.446473836898804
# Time for anizotropic=0.27031731605529785
# DONE with  10.447221279144287
# R=10.0, Zv=3.120781804101237, Zi=3.4697575242544314,B=0.10057639985323785, T=26.405685663223267
# start with jit and CALC!:  Fri Mar 13 09:52:25 2020
# FINISH IZotropic iterating with jit, T=16.29212760925293, flow=2.539121862317136
# ****************************************
#
# ANIZ!count=100, flow=2.7397764757483385,e=1, dev=10,w=1.95,T=16.379549980163574
# Finish !count=181, flow=2.7444140773115455,e=8.948558508255211e-08, dev=0.002289573272502211,w=1.95,T=16.446012496948242
# Time for anizotropic=0.1500403881072998
# DONE with  16.446749687194824
# start with jit and CALC!:  Fri Mar 13 09:52:41 2020
# FINISH IZotropic iterating with jit, T=11.101874589920044, flow=2.539121862317136
# ****************************************
#
# ANIZ!count=100, flow=3.050003321622271,e=1, dev=10,w=1.95,T=11.18697452545166
# ANIZ!count=200, flow=3.0656483773681082,e=6.4583961606576486e-06, dev=0.001098696899510123,w=1.95,T=11.268963813781738
# ANIZ!count=300, flow=3.066486616002048,e=3.119910141492332e-07, dev=0.0009185135079258386,w=1.95,T=11.353140354156494
# Finish !count=342, flow=3.0665241802739667,e=9.980694367522393e-08, dev=0.0009107179510101145,w=1.95,T=11.388589143753052
# Time for anizotropic=0.2828993797302246
# DONE with  11.389331579208374
# R=15.085907086001786, Zv=2.7444140773115455, Zi=3.0665241802739667,B=0.10504078364503344, T=28.329842805862427
# start with jit and CALC!:  Fri Mar 13 09:52:53 2020
# FINISH IZotropic iterating with jit, T=17.993144273757935, flow=2.3178343211005235
# ****************************************
#
# ANIZ!count=100, flow=2.589673682982933,e=1, dev=10,w=1.95,T=18.087570190429688
# Finish !count=168, flow=2.5953085644470963,e=1.606065358657205e-08, dev=0.0036633659339194865,w=1.95,T=18.149489879608154
# Time for anizotropic=0.1522657871246338
# DONE with  18.150318384170532
# start with jit and CALC!:  Fri Mar 13 09:53:11 2020
# FINISH IZotropic iterating with jit, T=12.400928735733032, flow=2.3178343211005235
# ****************************************
#
# ANIZ!count=100, flow=2.839375159346675,e=1, dev=10,w=1.95,T=12.503491163253784
# ANIZ!count=200, flow=2.8545337402962305,e=5.6106734576894315e-06, dev=0.004365859645068409,w=1.95,T=12.600087642669678
# ANIZ!count=300, flow=2.855299189337252,e=2.649523411649493e-07, dev=0.004194689764260358,w=1.95,T=12.699534177780151
# Finish !count=335, flow=2.85532857538686,e=9.923524055873573e-08, dev=0.0041888825919499315,w=1.95,T=12.73362922668457
# Time for anizotropic=0.3283560276031494
# DONE with  12.734485149383545
# R=22.758459260747887, Zv=2.5953085644470963, Zi=2.85532857538686,B=0.09106482986972331, T=31.263790607452393
# start with jit and CALC!:  Fri Mar 13 09:53:24 2020
# FINISH IZotropic iterating with jit, T=26.185805082321167, flow=2.249151396086995
# ****************************************
#
# ANIZ!count=100, flow=2.6285822968812553,e=1, dev=10,w=1.95,T=26.290097951889038
# ANIZ!count=200, flow=2.640121262426325,e=4.653991092256737e-06, dev=0.0022846348171827453,w=1.95,T=26.388919830322266
# ANIZ!count=300, flow=2.6408693463118733,e=5.544293907029478e-07, dev=0.0025006251076068876,w=1.95,T=26.500882625579834
# Finish !count=372, flow=2.6409313543502195,e=9.950146074352156e-08, dev=0.0025195206089610412,w=1.95,T=26.572669982910156
# Time for anizotropic=0.3822593688964844
# DONE with  26.573514938354492
# start with jit and CALC!:  Fri Mar 13 09:53:51 2020
# FINISH IZotropic iterating with jit, T=13.733117818832397, flow=2.249151396086995
# ****************************************
#
# ANIZ!count=100, flow=2.775711356099954,e=1, dev=10,w=1.95,T=13.840224266052246
# ANIZ!count=200, flow=2.787605074839432,e=3.737289149532627e-06, dev=0.0037829268881246223,w=1.95,T=13.942190170288086
# ANIZ!count=300, flow=2.788385384862953,e=2.996345868830873e-07, dev=0.0036334245794230487,w=1.95,T=14.050675630569458
# Finish !count=340, flow=2.7884180521783675,e=9.791011143685246e-08, dev=0.0036262850066240897,w=1.95,T=14.093376874923706
# Time for anizotropic=0.3555564880371094
# DONE with  14.094348192214966
# R=34.33320018281993, Zv=2.6409313543502195, Zi=2.7884180521783675,B=0.05289260615456437, T=41.022481203079224
# start with jit and CALC!:  Fri Mar 13 09:54:05 2020
# FINISH IZotropic iterating with jit, T=23.22027325630188, flow=1.783373076688201
# ****************************************
#
# ANIZ!count=100, flow=2.3555225514679234,e=1, dev=10,w=1.95,T=23.335113525390625
# ANIZ!count=200, flow=2.3956202122289927,e=2.7747700426017374e-05, dev=0.4937472115451723,w=1.95,T=23.445658445358276
# ANIZ!count=300, flow=2.398848469053151,e=5.088946914810766e-06, dev=0.49508953166803593,w=1.95,T=23.56008553504944
# ANIZ!count=400, flow=2.399162657113772,e=7.167105816607844e-07, dev=0.49531261226881873,w=1.95,T=23.66671633720398
# Finish !count=498, flow=2.399200147728527,e=9.919772925304216e-08, dev=0.4953429648309287,w=1.95,T=23.77837085723877
# Time for anizotropic=0.5512933731079102
# DONE with  23.779348373413086
# start with jit and CALC!:  Fri Mar 13 09:54:29 2020
# FINISH IZotropic iterating with jit, T=15.390891790390015, flow=1.783373076688201
# ****************************************
#
# ANIZ!count=100, flow=2.6539376210632133,e=1, dev=10,w=1.95,T=15.507907390594482
# ANIZ!count=200, flow=2.632893719330859,e=4.046140234881257e-05, dev=0.18166696387753667,w=1.95,T=15.61939024925232
# ANIZ!count=300, flow=2.6328287877740006,e=2.546365010208662e-06, dev=0.18297839820805575,w=1.95,T=15.73006820678711
# ANIZ!count=400, flow=2.632846306068612,e=1.677851045323031e-07, dev=0.1830626120646512,w=1.95,T=15.84170389175415
# Finish !count=420, flow=2.6328469004671735,e=9.84897909062088e-08, dev=0.18306518312713213,w=1.95,T=15.872721433639526
# Time for anizotropic=0.47470974922180176
# DONE with  15.873923778533936
# R=51.794746792312125, Zv=2.399200147728527, Zi=2.6328469004671735,B=0.08874300769147947, T=40.02756667137146
# start with jit and CALC!:  Fri Mar 13 09:54:45 2020
# FINISH IZotropic iterating with jit, T=13.764857769012451, flow=2.552778010729858
# ****************************************
#
# ANIZ!count=100, flow=3.428552853729162,e=1, dev=10,w=1.95,T=13.94061279296875
# ANIZ!count=200, flow=3.4196292920869586,e=2.669041789162723e-05, dev=0.0007895632768823855,w=1.95,T=14.097687244415283
# ANIZ!count=300, flow=3.419564204140582,e=1.4956074357107975e-06, dev=6.277064997352609e-06,w=1.95,T=14.253221035003662
# Finish !count=305, flow=3.419566079413589,e=2.0663244528593177e-08, dev=6.696411539516593e-07,w=1.95,T=14.261229753494263
# Time for anizotropic=0.4866294860839844
# DONE with  14.26265835762024
# start with jit and CALC!:  Fri Mar 13 09:55:00 2020
# FINISH IZotropic iterating with jit, T=5.702545166015625, flow=2.552778010729858
# ****************************************
#
# ANIZ!count=100, flow=3.241298266247039,e=1, dev=10,w=1.95,T=5.8714439868927
# Finish !count=186, flow=3.2584687364033593,e=8.939984215758498e-08, dev=0.00042021141342526324,w=1.95,T=6.0119569301605225
# Time for anizotropic=0.3019587993621826
# DONE with  6.013422012329102
# R=78.13707376518093, Zv=3.419566079413589, Zi=3.2584687364033593,B=-0.04943958529061909, T=20.749345541000366
# start with jit and CALC!:  Fri Mar 13 09:55:06 2020
# FINISH IZotropic iterating with jit, T=5.681375503540039, flow=2.5694909795499976
# ****************************************
#
# ANIZ!count=100, flow=3.410704640054875,e=1, dev=10,w=1.95,T=5.842990875244141
# ANIZ!count=200, flow=3.4057625086104393,e=2.2066099366158587e-05, dev=0.0005699042776644233,w=1.95,T=6.008188009262085
# ANIZ!count=300, flow=3.405797091013305,e=9.958486824235995e-07, dev=2.2599746051785662e-05,w=1.95,T=6.192100763320923
# Finish !count=391, flow=3.405817793835093,e=9.956157940761717e-08, dev=5.6491603506787654e-05,w=1.95,T=6.353430986404419
# Time for anizotropic=0.6649117469787598
# DONE with  6.354889869689941
# start with jit and CALC!:  Fri Mar 13 09:55:13 2020
# FINISH IZotropic iterating with jit, T=5.602026700973511, flow=2.5694909795499976
# ****************************************
#
# ANIZ!count=100, flow=3.3802817927973763,e=1, dev=10,w=1.95,T=5.785315752029419
# ANIZ!count=200, flow=3.399078044388711,e=2.5371058003389362e-05, dev=0.0005615082841880359,w=1.95,T=5.947068929672241
# ANIZ!count=300, flow=3.4002536122060487,e=1.3371140542204859e-06, dev=0.00017692978966815943,w=1.95,T=6.1256842613220215
# Finish !count=390, flow=3.4003168849826073,e=9.978501244750247e-08, dev=0.00021953999950782445,w=1.95,T=6.280644416809082
# Time for anizotropic=0.6702606678009033
# DONE with  6.2821044921875
# R=117.87686347935866, Zv=3.405817793835093, Zi=3.4003168849826073,B=-0.0016177635904408572, T=12.971309661865234
# start with jit and CALC!:  Fri Mar 13 09:55:19 2020
# FINISH IZotropic iterating with jit, T=5.538311004638672, flow=2.5756281387123185
# ****************************************
#
# ANIZ!count=100, flow=3.350321611365194,e=1, dev=10,w=1.95,T=5.706157207489014
# ANIZ!count=200, flow=3.346807585419494,e=1.9867643576126004e-05, dev=0.0005070659339362361,w=1.95,T=5.871947288513184
# ANIZ!count=300, flow=3.3468303343311216,e=7.45135425057538e-07, dev=8.838536801173083e-06,w=1.95,T=6.028803825378418
# Finish !count=377, flow=3.3468462939027552,e=9.844768335457651e-08, dev=1.461599033480961e-05,w=1.95,T=6.154129981994629
# Time for anizotropic=0.6082181930541992
# DONE with  6.155580997467041
# start with jit and CALC!:  Fri Mar 13 09:55:25 2020
# FINISH IZotropic iterating with jit, T=5.4842209815979, flow=2.5756281387123185
# ****************************************
#
# ANIZ!count=100, flow=3.5269363318661586,e=1, dev=10,w=1.95,T=5.653251886367798
# ANIZ!count=200, flow=3.5466660945610204,e=2.905945534456794e-05, dev=0.0007431713832291775,w=1.95,T=5.816311597824097
# ANIZ!count=300, flow=3.548014242019331,e=1.553885199141489e-06, dev=0.00011422703471295604,w=1.95,T=5.974656820297241
# Finish !count=395, flow=3.5480874668949873,e=9.974276409430334e-08, dev=0.00016421359612876852,w=1.95,T=6.127711296081543
# Time for anizotropic=0.635918140411377
# DONE with  6.129199504852295
# R=177.82794100389228, Zv=3.3468462939027552, Zi=3.5480874668949873,B=0.056718210830451365, T=12.595088720321655
# start with jit and CALC!:  Fri Mar 13 09:55:32 2020
# FINISH IZotropic iterating with jit, T=5.411288022994995, flow=2.5779901764817748
# ****************************************
#
# ANIZ!count=100, flow=3.287114911742358,e=1, dev=10,w=1.95,T=5.578184604644775
# ANIZ!count=200, flow=3.284269978205251,e=1.8595165620244997e-05, dev=0.000462254798122385,w=1.95,T=5.739133596420288
# ANIZ!count=300, flow=3.2842685455401175,e=5.944950851279247e-07, dev=1.9917094189653147e-05,w=1.95,T=5.89595365524292
# Finish !count=366, flow=3.2842802298279894,e=9.875280149947627e-08, dev=2.6739452275253482e-06,w=1.95,T=6.0012640953063965
# Time for anizotropic=0.5827319622039795
# DONE with  6.003206491470337
# start with jit and CALC!:  Fri Mar 13 09:55:38 2020
# FINISH IZotropic iterating with jit, T=5.415654420852661, flow=2.5779901764817748
# ****************************************
#
# ANIZ!count=100, flow=3.666388018027558,e=1, dev=10,w=1.95,T=5.581049919128418
# ANIZ!count=200, flow=3.6869266893802073,e=3.1679287920681714e-05, dev=0.0008714855699314691,w=1.95,T=5.743578672409058
# ANIZ!count=300, flow=3.688416922136489,e=1.7110688815928779e-06, dev=7.1199898791625e-05,w=1.95,T=5.902256011962891
# Finish !count=399, flow=3.688498510944596,e=9.748046164880148e-08, dev=0.0001266282117654129,w=1.95,T=6.0640459060668945
# Time for anizotropic=0.6408119201660156
# DONE with  6.0655317306518555
# R=268.2695795279727, Zv=3.2842802298279894, Zi=3.688498510944596,B=0.10958884215818465, T=12.38390564918518
# start with jit and CALC!:  Fri Mar 13 09:55:44 2020
# FINISH IZotropic iterating with jit, T=5.394034147262573, flow=2.578870350908648
# ****************************************
#
# ANIZ!count=100, flow=3.2322061281978103,e=1, dev=10,w=1.95,T=5.559605836868286
# ANIZ!count=200, flow=3.229726552075819,e=1.7802724657370057e-05, dev=0.00041570965578866507,w=1.95,T=5.719621658325195
# ANIZ!count=300, flow=3.229704713989248,e=4.988936309931033e-07, dev=8.561750165883747e-06,w=1.95,T=5.876936197280884
# Finish !count=357, flow=3.2297132746920796,e=9.857805071331863e-08, dev=4.737587737733887e-06,w=1.95,T=5.96821928024292
# Time for anizotropic=0.5670304298400879
# DONE with  5.969651460647583
# start with jit and CALC!:  Fri Mar 13 09:55:50 2020
# FINISH IZotropic iterating with jit, T=5.41408109664917, flow=2.578870350908648
# ****************************************
#
# ANIZ!count=100, flow=3.7898351956734944,e=1, dev=10,w=1.95,T=5.583632230758667
# ANIZ!count=200, flow=3.8110505145010554,e=3.348452782849843e-05, dev=0.0010169502869438866,w=1.95,T=5.748120069503784
# ANIZ!count=300, flow=3.8126526031745755,e=1.8206266485079505e-06, dev=1.5114896376662023e-05,w=1.95,T=5.906588315963745
# ANIZ!count=400, flow=3.8127405307372957,e=1.0075300605512908e-07, dev=4.3952699509798e-05,w=1.95,T=6.0689496994018555
# Finish !count=401, flow=3.8127406772896695,e=9.778796228903421e-08, dev=4.4050487472087036e-05,w=1.95,T=6.0706682205200195
# Time for anizotropic=0.6489260196685791
# DONE with  6.072063446044922
# R=404.70899507597613, Zv=3.2297132746920796, Zi=3.8127406772896695,B=0.15291556702776898, T=12.358718872070312
# start with jit and CALC!:  Fri Mar 13 09:55:56 2020
# FINISH IZotropic iterating with jit, T=5.402629613876343, flow=2.5791644531404208
# ****************************************
#
# ANIZ!count=100, flow=3.187742689093362,e=1, dev=10,w=1.95,T=5.56986141204834
# ANIZ!count=200, flow=3.185476779952546,e=1.728787243727016e-05, dev=0.00040904030472430677,w=1.95,T=5.728120803833008
# ANIZ!count=300, flow=3.185439857282498,e=4.3632635214639466e-07, dev=2.478564896261373e-05,w=1.95,T=5.88425350189209
# Finish !count=349, flow=3.185446235028116,e=9.537707983985132e-08, dev=1.4128705556099416e-05,w=1.95,T=5.961861610412598
# Time for anizotropic=0.5514814853668213
# DONE with  5.963284254074097
# start with jit and CALC!:  Fri Mar 13 09:56:03 2020
# FINISH IZotropic iterating with jit, T=5.492548227310181, flow=2.5791644531404208
# ****************************************
#
# ANIZ!count=100, flow=3.8935849056313465,e=1, dev=10,w=1.95,T=5.65623664855957
# ANIZ!count=200, flow=3.9153425162233164,e=3.472995958207835e-05, dev=0.0010607019127873286,w=1.95,T=5.815618991851807
# ANIZ!count=300, flow=3.9170291962128054,e=1.8943339144194293e-06, dev=1.901523870398086e-05,w=1.95,T=5.971380710601807
# ANIZ!count=400, flow=3.917121797637723,e=1.0479947399868523e-07, dev=4.243232201449659e-05,w=1.95,T=6.131601095199585
# Finish !count=402, flow=3.917122101885609,e=9.896527622915127e-08, dev=4.263299951212807e-05,w=1.95,T=6.134796857833862
# Time for anizotropic=0.6353635787963867
# DONE with  6.1361894607543945
# R=610.5402296585327, Zv=3.185446235028116, Zi=3.917122101885609,B=0.18678913953314902, T=12.405834436416626
# start with jit and CALC!:  Fri Mar 13 09:56:09 2020
# FINISH IZotropic iterating with jit, T=5.397969484329224, flow=2.579234360700439
# ****************************************
#
# ANIZ!count=100, flow=3.152717535429816,e=1, dev=10,w=1.95,T=5.562743902206421
# ANIZ!count=200, flow=3.1505770873791543,e=1.6943098065840933e-05, dev=0.0004816783305664054,w=1.95,T=5.722006559371948
# ANIZ!count=300, flow=3.150529165394749,e=3.9396945477030733e-07, dev=0.00011280437356100201,w=1.95,T=5.877826690673828
# Finish !count=343, flow=3.1505340925259526,e=9.811026605782496e-08, dev=0.00010389990614858251,w=1.95,T=5.94531512260437
# Time for anizotropic=0.5403974056243896
# DONE with  5.9468092918396
# start with jit and CALC!:  Fri Mar 13 09:56:15 2020
# FINISH IZotropic iterating with jit, T=5.398866415023804, flow=2.579234360700439
# ****************************************
#
# ANIZ!count=100, flow=3.9781489641518197,e=1, dev=10,w=1.95,T=5.563274383544922
# ANIZ!count=200, flow=4.000317428779455,e=3.5557209355873646e-05, dev=0.000997869164954897,w=1.95,T=5.723194122314453
# ANIZ!count=300, flow=4.0020648955220075,e=1.941484129517685e-06, dev=6.99278546043665e-05,w=1.95,T=5.878826141357422
# ANIZ!count=400, flow=4.0021607942798045,e=1.0731606386949811e-07, dev=0.00013288664928279783,w=1.95,T=6.038048982620239
# Finish !count=403, flow=4.0021612598129455,e=9.853614949415705e-08, dev=0.00013319067458919515,w=1.95,T=6.042827844619751
# Time for anizotropic=0.6370277404785156
# DONE with  6.0442235469818115
# R=921.055317689482, Zv=3.1505340925259526, Zi=4.0021612598129455,B=0.2127918172209774, T=12.297586679458618
# start with jit and CALC!:  Fri Mar 13 09:56:21 2020
# FINISH IZotropic iterating with jit, T=5.396598815917969, flow=2.579226150627908
# ****************************************
#
# ANIZ!count=100, flow=3.125741400347472,e=1, dev=10,w=1.95,T=5.560917139053345
# ANIZ!count=200, flow=3.1236772344701813,e=1.670951743006874e-05, dev=0.0004135408498842532,w=1.95,T=5.719623565673828
# ANIZ!count=300, flow=3.123621307642991,e=3.646271688018422e-07, dev=5.521586301935587e-05,w=1.95,T=5.8761982917785645
# Finish !count=339, flow=3.1236252806787324,e=9.980745264798424e-08, dev=4.746645363694587e-05,w=1.95,T=5.937543153762817
# Time for anizotropic=0.5339200496673584
# DONE with  5.938990354537964
# start with jit and CALC!:  Fri Mar 13 09:56:27 2020
# FINISH IZotropic iterating with jit, T=5.584538459777832, flow=2.579226150627908
# ****************************************
#
# ANIZ!count=100, flow=4.0473800196350815,e=1, dev=10,w=1.95,T=5.7716381549835205
# ANIZ!count=200, flow=4.069830504927079,e=3.61042179974568e-05, dev=0.0020136325348630167,w=1.95,T=5.940963268280029
# ANIZ!count=300, flow=4.071619912231318,e=1.972780112044232e-06, dev=0.000927830567174081,w=1.95,T=6.104384422302246
# ANIZ!count=400, flow=4.071718009770156,e=1.089129342344685e-07, dev=0.000863881911677459,w=1.95,T=6.269963264465332
# Finish !count=403, flow=4.071718485507969,e=9.99971221855335e-08, dev=0.000863573374706592,w=1.95,T=6.274995565414429
# Time for anizotropic=0.6819624900817871
# DONE with  6.2764599323272705
# R=1389.4954943731375, Zv=3.1236252806787324, Zi=4.071718485507969,B=0.23284841724782368, T=12.527275800704956
# start with jit and CALC!:  Fri Mar 13 09:56:34 2020
# FINISH IZotropic iterating with jit, T=5.443607330322266, flow=2.5791968145015574
# ****************************************
#
# ANIZ!count=100, flow=3.1047041227489602,e=1, dev=10,w=1.95,T=5.613002300262451
# ANIZ!count=200, flow=3.1027019585833804,e=1.6536810598400298e-05, dev=0.0003198786528593339,w=1.95,T=5.775883436203003
# ANIZ!count=300, flow=3.1026405914119946,e=3.440488296592648e-07, dev=3.094069462488159e-05,w=1.95,T=5.932000398635864
# Finish !count=337, flow=3.10264397564375,e=9.935896873244514e-08, dev=3.798484741101716e-05,w=1.95,T=5.990309238433838
# Time for anizotropic=0.5391120910644531
# DONE with  5.991751670837402
# start with jit and CALC!:  Fri Mar 13 09:56:40 2020
# FINISH IZotropic iterating with jit, T=5.464740991592407, flow=2.5791968145015574
# ****************************************
#
# ANIZ!count=100, flow=4.101226900386328,e=1, dev=10,w=1.95,T=5.627600908279419
# ANIZ!count=200, flow=4.123942291650312,e=3.646216714421266e-05, dev=0.002038915006724306,w=1.95,T=5.785948753356934
# ANIZ!count=300, flow=4.125764888021536,e=1.9940751818233945e-06, dev=0.0009410881703014305,w=1.95,T=5.940595865249634
# ANIZ!count=400, flow=4.12586474810907,e=1.1002812116522442e-07, dev=0.0008764603373075752,w=1.95,T=6.09762978553772
# Finish !count=404, flow=4.125865384236359,e=9.821392841927526e-08, dev=0.000876050434511952,w=1.95,T=6.1042869091033936
# Time for anizotropic=0.6327030658721924
# DONE with  6.105653524398804
# R=2096.179992453128, Zv=3.10264397564375, Zi=4.125865384236359,B=0.24800164651566636, T=12.412769317626953
# start with jit and CALC!:  Fri Mar 13 09:56:46 2020
# FINISH IZotropic iterating with jit, T=5.382777690887451, flow=2.5791668838652413
# ****************************************
#
# ANIZ!count=100, flow=3.089568740369282,e=1, dev=10,w=1.95,T=5.552557945251465
# ANIZ!count=200, flow=3.0875982853234603,e=1.6411185296075713e-05, dev=0.0004816282247246795,w=1.95,T=5.715768337249756
# ANIZ!count=300, flow=3.087533263082821,e=3.2997945620058273e-07, dev=0.00013619337529207823,w=1.95,T=5.873193979263306
# Finish !count=336, flow=3.087536286150546,e=9.887875246312799e-08, dev=0.00012958406351093926,w=1.95,T=5.930418014526367
# Time for anizotropic=0.5396575927734375
# DONE with  5.9318671226501465
# start with jit and CALC!:  Fri Mar 13 09:56:52 2020
# FINISH IZotropic iterating with jit, T=5.737957954406738, flow=2.5791668838652413
# ****************************************
#
# ANIZ!count=100, flow=4.141324307906756,e=1, dev=10,w=1.95,T=5.904149532318115
# ANIZ!count=200, flow=4.164291724399016,e=3.6766389709319645e-05, dev=0.0013417309940414123,w=1.95,T=6.062757730484009
# ANIZ!count=300, flow=4.16614541645956,e=2.0151607700457817e-06, dev=0.00023327251019899384,w=1.95,T=6.217883348464966
# ANIZ!count=400, flow=4.166247090548017,e=1.1129565206618292e-07, dev=0.0001679443891083869,w=1.95,T=6.376399993896484
# Finish !count=404, flow=4.166247738610133,e=9.93459064928346e-08, dev=0.0001675297616683988,w=1.95,T=6.383065938949585
# Time for anizotropic=0.6380321979522705
# DONE with  6.3844685554504395
# R=3162.2776601683795, Zv=3.087536286150546, Zi=4.166247738610133,B=0.2589167807912084, T=12.716404914855957
# DONE 403.5652379989624

# %%
from l2020_anizotropic import LiebmanAniz

# %%
from time import time
# %matplotlib inline
start=time()
zv=LiebmanAniz('one',5,55,3000, P=-12., _w=1.95, dr=0.5,dz=0.5)
Zv=zv['flow']
print ('Zv=',Zv)
print ('Time=',time()-start)
zi=LiebmanAniz('one',5,55,3000, P=24., _w=1.95, dr=0.5,dz=0.5)
Zi=zi['flow']

print ('Zv=',Zv)
print ('Zi=',Zi)
print ('B=',1-Zv/Zi)
print ('Time=',time()-start)
# Out:
# start with jit and CALC!:  Tue Feb 18 10:38:33 2020
# Start fill the matrixes
# Time for coefficient calculation: 3.2846109867095947
# Finish fill the matrixes, T=3.6767725944519043
# ****************************************
#
# start Anizotropic
# ANIZ!count=500, flow=3.133766355434947,e=4.469169130744133e-07, dev=0.07756215839510319,w=1.95,T=12.306171417236328
# ANIZ!count=1000, flow=3.133735427121326,e=1.1757539386536564e-12, dev=0.07754502053864813,w=1.95,T=13.491841554641724
# ANIZ!count=1500, flow=3.1337354270394604,e=2.2898349882893854e-15, dev=0.0775450204932853,w=1.95,T=14.427548170089722
# ANIZ!count=2000, flow=3.1337354270394684,e=1.3877787807814457e-16, dev=0.07754502049328764,w=1.95,T=15.32478642463684
# ANIZ!count=2500, flow=3.133735427039464,e=3.469446951953614e-16, dev=0.07754502049329384,w=1.95,T=16.23970937728882
# ANIZ!count=3000, flow=3.1337354270394604,e=1.1379786002407855e-15, dev=0.07754502049329152,w=1.95,T=17.138521909713745
# ...

# %%
2**16
# Out:
# 65536
